# %%
file_path = ("data/")

# %%
import argparse
import os
import shutil
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema.document import Document

# %%
def load_documents():
    document_loader = PyPDFDirectoryLoader(file_path)
    return document_loader.load()

# %%
def split_documents(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)

# %%
documents = load_documents()
print(documents[0])
chunks = split_documents(documents)
# Out:
# page_content='' metadata={'source': 'data/harrypotter.pdf', 'page': 0}

# %%
#from langchain_community.embeddings.ollama import OllamaEmbeddings
#from langchain_community.embeddings.bedrock import BedrockEmbeddings

from langchain_ollama import OllamaEmbeddings

def get_embedding_function():
    #embeddings = BedrockEmbeddings(
    #    credentials_profile_name="default", region_name="us-east-1"
    #)
    embeddings = OllamaEmbeddings(model="nomic-embed-text")
    return embeddings

# %%
#from get_embedding_function import get_embedding_function
#from langchain.vectorstores.chroma import Chroma
from langchain_chroma import Chroma

CHROMA_PATH = "chroma"

# %%
def add_to_chroma(chunks: list[Document]):
    # Load the existing database.
    db = Chroma(
        persist_directory=CHROMA_PATH, embedding_function=get_embedding_function()
    )

    # Calculate Page IDs.
    chunks_with_ids = calculate_chunk_ids(chunks)

    # Add or Update the documents.
    existing_items = db.get(include=[])  # IDs are always included by default
    existing_ids = set(existing_items["ids"])
    print(f"Number of existing documents in DB: {len(existing_ids)}")

    # Only add documents that don't exist in the DB.
    new_chunks = []
    for chunk in chunks_with_ids:
        if chunk.metadata["id"] not in existing_ids:
            new_chunks.append(chunk)

    if len(new_chunks):
        print(f"👉 Adding new documents: {len(new_chunks)}")
        new_chunk_ids = [chunk.metadata["id"] for chunk in new_chunks]
        db.add_documents(new_chunks, ids=new_chunk_ids)
        db.persist()
    else:
        print("✅ No new documents to add")


def calculate_chunk_ids(chunks):

    # This will create IDs like "data/monopoly.pdf:6:2"
    # Page Source : Page Number : Chunk Index

    last_page_id = None
    current_chunk_index = 0

    for chunk in chunks:
        source = chunk.metadata.get("source")
        page = chunk.metadata.get("page")
        current_page_id = f"{source}:{page}"

        # If the page ID is the same as the last one, increment the index.
        if current_page_id == last_page_id:
            current_chunk_index += 1
        else:
            current_chunk_index = 0

        # Calculate the chunk ID.
        chunk_id = f"{current_page_id}:{current_chunk_index}"
        last_page_id = current_page_id

        # Add it to the page meta-data.
        chunk.metadata["id"] = chunk_id

    return chunks


def clear_database():
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)

# %%
def add_to_chroma(chunks: list[Document]):
    """Add new documents to the Chroma DB, skipping those that already exist."""
    
    try:
        # Load the existing Chroma database.
        db = Chroma(
            persist_directory=CHROMA_PATH, 
            embedding_function=get_embedding_function()
        )

        # Calculate IDs for chunks.
        chunks_with_ids = calculate_chunk_ids(chunks)

        # Get existing documents in the DB.
        existing_items = db.get(include=[])  # IDs are always included by default
        existing_ids = set(existing_items["ids"])
        print(f"Number of existing documents in DB: {len(existing_ids)}")

        # Filter out the chunks that already exist in the DB.
        new_chunks = [chunk for chunk in chunks_with_ids if chunk.metadata["id"] not in existing_ids]

        if new_chunks:
            print(f"👉 Adding new documents: {len(new_chunks)}")
            new_chunk_ids = [chunk.metadata["id"] for chunk in new_chunks]
            db.add_documents(new_chunks, ids=new_chunk_ids)
        else:
            print("✅ No new documents to add")
    except Exception as e:
        print(f"❌ Error while adding to Chroma: {str(e)}")

def calculate_chunk_ids(chunks: list[Document]) -> list[Document]:
    """Generate unique IDs for each document chunk."""
    
    last_page_id = None
    current_chunk_index = 0

    for chunk in chunks:
        source = chunk.metadata.get("source")
        page = chunk.metadata.get("page")
        current_page_id = f"{source}:{page}"

        # Increment chunk index if still on the same page.
        if current_page_id == last_page_id:
            current_chunk_index += 1
        else:
            current_chunk_index = 0

        # Create the chunk ID using source, page, and chunk index.
        chunk_id = f"{current_page_id}:{current_chunk_index}"
        chunk.metadata["id"] = chunk_id
        last_page_id = current_page_id

    return chunks

def clear_database():
    """Delete the existing Chroma DB."""
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)
        print(f"✅ Database at {CHROMA_PATH} cleared.")
    else:
        print(f"⚠️ No database found at {CHROMA_PATH} to clear.")

# %%
add_to_chroma(chunks)
# Out:
# Number of existing documents in DB: 10215
# ✅ No new documents to add

# %%
os.system("ollama pull nomic-embed-text")
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠇ pulling manifest ⠋ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏ 224 KB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕                ▏ 504 KB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   1% ▕                ▏ 2.0 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   2% ▕                ▏ 4.3 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   2% ▕                ▏ 6.2 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...   3% ▕                ▏ 8.9 MB/274 MB                  pulling manifest
# pulling 970aa74c0a90...  30% ▕████            ▏  83 MB/274 MB   16 MB/s     11spulling manifest
# pulling 970aa74c0a90...  32% ▕█████           ▏  87 MB/274 MB   16 MB/s     11spulling manifest
# pulling 970aa74c0a90...  33% ▕█████           ▏  89 MB/274 MB   17 MB/s     10spulling manifest
# pulling 970aa74c0a90...  33% ▕█████           ▏  90 MB/274 MB   17 MB/s     10spulling manifest
# pulling 970aa74c0a90...  34% ▕█████           ▏  92 MB/274 MB   17 MB/s     10spulling manifest
# pulling 970aa74c0a90...  35% ▕█████           ▏  95 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  35% ▕█████           ▏  96 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  36% ▕█████           ▏  98 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  37% ▕█████           ▏ 100 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  37% ▕█████           ▏ 101 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  38% ▕██████          ▏ 104 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  39% ▕██████          ▏ 107 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  40% ▕██████          ▏ 109 MB/274 MB   17 MB/s      9spulling manifest
# pulling 970aa74c0a90...  41% ▕██████          ▏ 111 MB/274 MB   18 MB/s      8spulling manifest
# pulling 970aa74c0a90...  42% ▕██████          ▏ 114 MB/274 MB   18 MB/s      8spulling manifest
# pulling 970aa74c0a90...  42% ▕██████          ▏ 115 MB/274 MB   18 MB/s      8spulling manifest
# pulling 970aa74c0a90...  43% ▕██████          ▏ 118 MB/274 MB   18 MB/s      8spulling manifest
# pulling 970aa74c0a90...  44% ▕███████         ▏ 121 MB/274 MB   18 MB/s      8spulling manifest
# pulling 970aa74c0a90...  45% ▕███████         ▏ 122 MB/274 MB   18 MB/s      8spulling manifest
# pulling 970aa74c0a90...  46% ▕███████         ▏ 125 MB/274 MB   18 MB/s      8spulling manifest
# pulling 970aa74c0a90...  47% ▕███████         ▏ 129 MB/274 MB   18 MB/s      7spulling manifest
# pulling 970aa74c0a90...  48% ▕███████         ▏ 130 MB/274 MB   18 MB/s      7spulling manifest
# pulling 970aa74c0a90...  49% ▕███████         ▏ 133 MB/274 MB   18 MB/s      7spulling manifest
# pulling 970aa74c0a90...  49% ▕███████         ▏ 135 MB/274 MB   19 MB/s      7spulling manifest
# pulling 970aa74c0a90...  50% ▕███████         ▏ 136 MB/274 MB   19 MB/s      7spulling manifest
# pulling 970aa74c0a90...  51% ▕████████        ▏ 139 MB/274 MB   19 MB/s      6spulling manifest
# pulling 970aa74c0a90...  52% ▕████████        ▏ 142 MB/274 MB   19 MB/s      6spulling manifest
# pulling 970aa74c0a90...  52% ▕████████        ▏ 143 MB/274 MB   19 MB/s      6spulling manifest
# pulling 970aa74c0a90...  53% ▕████████        ▏ 145 MB/274 MB   19 MB/s      6spulling manifest
# pulling 970aa74c0a90...  78% ▕████████████    ▏ 214 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  79% ▕████████████    ▏ 216 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  79% ▕████████████    ▏ 217 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  80% ▕████████████    ▏ 219 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  81% ▕████████████    ▏ 220 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  81% ▕████████████    ▏ 222 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  82% ▕█████████████   ▏ 224 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  82% ▕█████████████   ▏ 226 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  83% ▕█████████████   ▏ 227 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  83% ▕█████████████   ▏ 228 MB/274 MB   22 MB/s      2spulling manifest
# pulling 970aa74c0a90...  84% ▕█████████████   ▏ 230 MB/274 MB   22 MB/s      1spulling manifest
# pulling 970aa74c0a90...  85% ▕█████████████   ▏ 232 MB/274 MB   22 MB/s      1spulling manifest
# pulling 970aa74c0a90...  86% ▕█████████████   ▏ 234 MB/274 MB   22 MB/s      1spulling manifest
# pulling 970aa74c0a90...  86% ▕█████████████   ▏ 236 MB/274 MB   22 MB/s      1spulling manifest
# pulling 970aa74c0a90...  86% ▕█████████████   ▏ 236 MB/274 MB   22 MB/s      1spulling manifest
# pulling 970aa74c0a90...  87% ▕█████████████   ▏ 237 MB/274 MB   22 MB/s      1spulling manifest
# pulling 970aa74c0a90...  87% ▕█████████████   ▏ 238 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  87% ▕█████████████   ▏ 239 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  88% ▕██████████████  ▏ 240 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  88% ▕██████████████  ▏ 241 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  88% ▕██████████████  ▏ 241 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  88% ▕██████████████  ▏ 241 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  88% ▕██████████████  ▏ 241 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  88% ▕██████████████  ▏ 242 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  88% ▕██████████████  ▏ 242 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  89% ▕██████████████  ▏ 243 MB/274 MB   21 MB/s      1spulling manifest
# pulling 970aa74c0a90...  89% ▕██████████████  ▏ 244 MB/274 MB   19 MB/s      1spulling manifest
# pulling 970aa74c0a90...  90% ▕██████████████  ▏ 245 MB/274 MB   19 MB/s      1spulling manifest
B                  pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa...   0% ▕                ▏    0 B/ 420 B                  pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa...   0% ▕                ▏    0 B/ 420 B                  pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa... 100% ▕████████████████▏  420 B                         pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa... 100% ▕████████████████▏  420 B                         pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa... 100% ▕████████████████▏  420 B                         pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa... 100% ▕████████████████▏  420 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 970aa74c0a90... 100% ▕████████████████▏ 274 MB
# pulling c71d239df917... 100% ▕████████████████▏  11 KB
# pulling ce4a164fc046... 100% ▕████████████████▏   17 B
# pulling 31df23ea7daa... 100% ▕████████████████▏  420 B
# verifying sha256 digest
# writing manifest
# success
# 0

# %%
os.system("ollama pull llama3.2")
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠇ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠴ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏  59 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 342 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 506 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 1.2 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 3.0 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 3.6 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 5.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 6.7 MB/2.0 GB  3.1 MB/s  10m57spulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 7.3 MB/2.0 GB  3.1 MB/s  10m57spulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 8.1 MB/2.0 GB  3.1 MB/s  10m57spulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 9.0 MB/2.0 GB  3.1 MB/s  10m57spulling manifest
# pulling dde5aa3fc5ff...   0% ▕                ▏ 9.8 MB/2.0 GB  3.1 MB/s  10m56spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  12 MB/2.0 GB  3.1 MB/s  10m56spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  14 MB/2.0 GB  3.1 MB/s  10m55spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  16 MB/2.0 GB  3.1 MB/s  10m54spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  17 MB/2.0 GB  3.1 MB/s  10m54spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  19 MB/2.0 GB  3.1 MB/s  10m53spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  20 MB/2.0 GB  6.9 MB/s   4m51spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  21 MB/2.0 GB  6.9 MB/s   4m51spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  24 MB/2.0 GB  6.9 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  26 MB/2.0 GB  6.9 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff...   1% ▕                ▏  30 MB/2.0 GB  6.9 MB/s   4m50spulling manifest
# pulling dde5aa3fc5ff...   2% ▕                ▏  33 MB/2.0 GB  6.9 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff...   2% ▕                ▏  35 MB/2.0 GB  6.9 MB/s   4m49spulling manifest
# pulling dde5aa3fc5ff...   2% ▕                ▏  39 MB/2.0 GB  6.9 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff...   2% ▕                ▏  42 MB/2.0 GB  6.9 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff...   2% ▕                ▏  43 MB/2.0 GB  6.9 MB/s   4m48spulling manifest
# pulling dde5aa3fc5ff...   2% ▕                ▏  47 MB/2.0 GB   11 MB/s   2m46spulling manifest
# pulling dde5aa3fc5ff...   2% ▕                ▏  49 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff...   3% ▕                ▏  51 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff...   3% ▕                ▏  54 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff...   3% ▕                ▏  56 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff...   3% ▕                ▏  58 MB/2.0 GB   11 MB/s   2m45spulling manifest
# pulling dde5aa3fc5ff...   3% ▕                ▏  62 MB/2.0 GB   11 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff...   3% ▕                ▏  65 MB/2.0 GB   11 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff...   3% ▕                ▏  67 MB/2.0 GB   11 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  72 MB/2.0 GB   11 MB/s   2m44spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  76 MB/2.0 GB   15 MB/s    2m7spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  77 MB/2.0 GB   15 MB/s    2m7spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  80 MB/2.0 GB   15 MB/s    2m7spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  83 MB/2.0 GB   15 MB/s    2m6spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  85 MB/2.0 GB   15 MB/s    2m6spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  87 MB/2.0 GB   15 MB/s    2m6spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏  89 MB/2.0 GB   15 MB/s    2m6spulling manifest
# pulling dde5aa3fc5ff...   4% ▕                ▏
ulling manifest
# pulling dde5aa3fc5ff...  11% ▕█               ▏ 221 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  11% ▕█               ▏ 224 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  11% ▕█               ▏ 226 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  11% ▕█               ▏ 228 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  11% ▕█               ▏ 231 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 233 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 235 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 238 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 239 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 241 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 245 MB/2.0 GB   22 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 245 MB/2.0 GB   22 MB/s   1m20spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 248 MB/2.0 GB   22 MB/s   1m20spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 250 MB/2.0 GB   22 MB/s   1m20spulling manifest
# pulling dde5aa3fc5ff...  12% ▕█               ▏ 252 MB/2.0 GB   22 MB/s   1m20spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 253 MB/2.0 GB   22 MB/s   1m20spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 255 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 257 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 260 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 263 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 264 MB/2.0 GB   22 MB/s   1m19spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 266 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 269 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  13% ▕██              ▏ 270 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  14% ▕██              ▏ 273 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  14% ▕██              ▏ 277 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  14% ▕██              ▏ 278 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  14% ▕██              ▏ 281 MB/2.0 GB   21 MB/s   1m22spulling manifest
# pulling dde5aa3fc5ff...  14% ▕██              ▏ 284 MB/2.0 GB   21 MB/s   1m21spulling manifest
# pulling dde5aa3fc5ff...  14% ▕██              ▏ 286 MB/2.0 GB   21 MB/s   1m21spulling manifest
# pulling dde5aa3fc5ff...  14% ▕██              ▏ 289 MB/2.0 GB   21 MB/s   1m21spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 293 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 294 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 298 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 302 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 302 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 306 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 309 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  15% ▕██              ▏ 311 MB/2.0 GB   21 MB/s   1m18spulling manifest
# pulling dde5aa3fc5ff...  16% ▕██              ▏ 314 MB/2.0 GB   21 MB/s   1m17spulling manifest
# pulling dde5aa3fc5ff...  16% ▕██              ▏ 317 MB/2.0 GB   21 MB/s   1m17spulling manifest
# pulling dde5aa3fc5ff...  16% ▕██              ▏ 319 MB/2.0 GB   21 MB/s   1m17spulling manifest
# pulling dde5aa3fc5ff...  16% ▕██              ▏ 323 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  16% ▕██              ▏ 327 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  16% ▕██              ▏ 328 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  16% ▕██              ▏ 331 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 334 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 335 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 337 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 340 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 340 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 344 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 346 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 348 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  17% ▕██              ▏ 350 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 353 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 354 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 358 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 361 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 362 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 364 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 366 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 367 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 369 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  18% ▕██              ▏ 372 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  19% ▕██              ▏ 373 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  19% ▕██              ▏ 377 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 379 MB/2.0 GB   22 MB/s   1m11spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 380 MB/2.0 GB   22 MB/s   1m11spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 382 MB/2.0 GB   22 MB/s   1m11spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 385 MB/2.0 GB   22 MB/s   1m11spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 387 MB/2.0 GB   22 MB/s   1m11spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 389 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 391 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  19% ▕███             ▏ 392 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 395 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 397 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 399 MB/2.0 GB   22 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 403 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 405 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 406 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 409 MB/2.0 GB   22 MB/s   1m12spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 412 MB/2.0 GB   23 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  20% ▕███             ▏ 413 MB/2.0 GB   23 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 415 MB/2.0 GB   23 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 417 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 417 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 419 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 419 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 420 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 421 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 423 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 424 MB/2.0 GB   23 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 426 MB/2.0 GB   22 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  21% ▕███             ▏ 428 MB/2.0 GB   22 MB/s   1m10spulling manifest
# pulling dde5aa3fc5
MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  25% ▕████            ▏ 513 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 516 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 519 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 520 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 523 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 527 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 528 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 530 MB/2.0 GB   21 MB/s   1m10spulling manifest
# pulling dde5aa3fc5ff...  26% ▕████            ▏ 533 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 535 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 538 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 540 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 541 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 544 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 547 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 548 MB/2.0 GB   21 MB/s    1m9spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 551 MB/2.0 GB   21 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  27% ▕████            ▏ 555 MB/2.0 GB   21 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  28% ▕████            ▏ 556 MB/2.0 GB   21 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  28% ▕████            ▏ 559 MB/2.0 GB   21 MB/s    1m8spulling manifest
# pulling dde5aa3fc5ff...  28% ▕████            ▏ 561 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  28% ▕████            ▏ 563 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  28% ▕████            ▏ 567 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  28% ▕████            ▏ 570 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  28% ▕████            ▏ 572 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  29% ▕████            ▏ 575 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  29% ▕████            ▏ 579 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  29% ▕████            ▏ 581 MB/2.0 GB   21 MB/s    1m7spulling manifest
# pulling dde5aa3fc5ff...  29% ▕████            ▏ 584 MB/2.0 GB   21 MB/s    1m6spulling manifest
# pulling dde5aa3fc5ff...  29% ▕████            ▏ 588 MB/2.0 GB   21 MB/s    1m6spulling manifest
# pulling dde5aa3fc5ff...  29% ▕████            ▏ 590 MB/2.0 GB   22 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  29% ▕████            ▏ 594 MB/2.0 GB   22 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  30% ▕████            ▏ 597 MB/2.0 GB   22 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  30% ▕████            ▏ 599 MB/2.0 GB   22 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  30% ▕████            ▏ 603 MB/2.0 GB   22 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  30% ▕████            ▏ 608 MB/2.0 GB   22 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  30% ▕████            ▏ 610 MB/2.0 GB   22 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  30% ▕████            ▏ 613 MB/2.0 GB   22 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  31% ▕████            ▏ 617 MB/2.0 GB   22 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  31% ▕████            ▏ 619 MB/2.0 GB   22 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  31% ▕████            ▏ 623 MB/2.0 GB   23 MB/s     59spulling manifest
# pulling dde5aa3fc5ff...  31% ▕████            ▏ 626 MB/2.0 GB   23 MB/s     59spulling manifest
# pulling dde5aa3fc5ff...  31% ▕████            ▏ 628 MB/2.0 GB   23 MB/s     59spulling manifest
# pulling dde5aa3fc5ff...  31% ▕█████           ▏ 631 MB/2.0 GB   23 MB/s     59spulling manifest
# pulling dde5aa3fc5ff...  31% ▕█████           ▏ 634 MB/2.0 GB   23 MB/s     59spulling manifest
# pulling dde5aa3fc5ff...  31% ▕█████           ▏ 636 MB/2.0 GB   23 MB/s     58spulling manifest
# pulling dde5aa3fc5ff...  32% ▕█████           ▏ 637 MB/2.0 GB   23 MB/s     58spulling manifest
# pulling dde5aa3fc5ff...  32% ▕█████           ▏ 640 MB/2.0 GB   23 MB/s     58spulling manifest
# pulling dde5aa3fc5ff...  32% ▕█████           ▏ 641 MB/2.0 GB   23 MB/s     58spulling manifest
# pulling dde5aa3fc5ff...  32% ▕█████           ▏ 645 MB/2.0 GB   23 MB/s     58spulling manifest
# pulling dde5aa3fc5ff...  32% ▕█████           ▏ 648 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  32% ▕█████           ▏ 649 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  32% ▕█████           ▏ 653 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 656 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 657 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 658 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 659 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 659 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 660 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 661 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 661 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 663 MB/2.0 GB   24 MB/s     56spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 665 MB/2.0 GB   24 MB/s     56spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 666 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 667 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 670 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 672 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 672 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  33% ▕█████           ▏ 675 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 676 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 678 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 681 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 683 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 686 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 689 MB/2.0 GB   24 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 690 MB/2.0 GB   24 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 693 MB/2.0 GB   24 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  34% ▕█████           ▏ 695 MB/2.0 GB   24 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 696 MB/2.0 GB   24 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 698 MB/2.0 GB   24 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 701 MB/2.0 GB   24 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 702 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 703 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 707 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 708 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 711 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 713 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  35% ▕█████           ▏ 714 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 716 MB/2.0 GB   23 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 717 MB/2.0 GB   23 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 719 MB/2.0 GB   23 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 721 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 722 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 722 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 724 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 724 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 724 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 725 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 725 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 725 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 726 MB/2.0 GB   23 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 726 MB/2.0 GB   21 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 726 MB/2.0 GB   21 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 726 MB/2.0 GB   21 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 727 MB/2.0 GB   21 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 727 MB/2.0 GB   21 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 728 MB/2.0 GB   21 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  36% ▕█████           ▏ 729 MB/2.0 GB   21 MB/s    1m1spulling manifest
# pulling dde5aa3fc5
# pulling dde5aa3fc5ff...  37% ▕█████           ▏ 754 MB/2.0 GB   13 MB/s   1m32spulling manifest
# pulling dde5aa3fc5ff...  37% ▕█████           ▏ 756 MB/2.0 GB   12 MB/s   1m44spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 758 MB/2.0 GB   12 MB/s   1m44spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 759 MB/2.0 GB   12 MB/s   1m44spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 760 MB/2.0 GB   12 MB/s   1m44spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 763 MB/2.0 GB   12 MB/s   1m44spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 764 MB/2.0 GB   12 MB/s   1m44spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 766 MB/2.0 GB   12 MB/s   1m44spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 768 MB/2.0 GB   12 MB/s   1m43spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 769 MB/2.0 GB   12 MB/s   1m43spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 772 MB/2.0 GB   12 MB/s   1m43spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 774 MB/2.0 GB   12 MB/s   1m39spulling manifest
# pulling dde5aa3fc5ff...  38% ▕██████          ▏ 776 MB/2.0 GB   12 MB/s   1m39spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 778 MB/2.0 GB   12 MB/s   1m39spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 781 MB/2.0 GB   12 MB/s   1m39spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 782 MB/2.0 GB   12 MB/s   1m38spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 786 MB/2.0 GB   12 MB/s   1m38spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 789 MB/2.0 GB   12 MB/s   1m38spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 790 MB/2.0 GB   12 MB/s   1m38spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 793 MB/2.0 GB   12 MB/s   1m38spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 795 MB/2.0 GB   12 MB/s   1m37spulling manifest
# pulling dde5aa3fc5ff...  39% ▕██████          ▏ 796 MB/2.0 GB   12 MB/s   1m37spulling manifest
# pulling dde5aa3fc5ff...  40% ▕██████          ▏ 798 MB/2.0 GB   13 MB/s   1m33spulling manifest
# pulling dde5aa3fc5ff...  40% ▕██████          ▏ 801 MB/2.0 GB   13 MB/s   1m33spulling manifest
# pulling dde5aa3fc5ff...  40% ▕██████          ▏ 803 MB/2.0 GB   13 MB/s   1m33spulling manifest
# pulling dde5aa3fc5ff...  40% ▕██████          ▏ 806 MB/2.0 GB   13 MB/s   1m33spulling manifest
# pulling dde5aa3fc5ff...  40% ▕██████          ▏ 809 MB/2.0 GB   13 MB/s   1m32spulling manifest
# pulling dde5aa3fc5ff...  40% ▕██████          ▏ 811 MB/2.0 GB   13 MB/s   1m32spulling manifest
# pulling dde5aa3fc5ff...  40% ▕██████          ▏ 814 MB/2.0 GB   13 MB/s   1m32spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 817 MB/2.0 GB   13 MB/s   1m32spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 819 MB/2.0 GB   13 MB/s   1m32spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 823 MB/2.0 GB   13 MB/s   1m31spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 827 MB/2.0 GB   13 MB/s   1m27spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 828 MB/2.0 GB   13 MB/s   1m27spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 829 MB/2.0 GB   13 MB/s   1m27spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 830 MB/2.0 GB   13 MB/s   1m27spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 831 MB/2.0 GB   13 MB/s   1m27spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 833 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 835 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  41% ▕██████          ▏ 837 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 840 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 842 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 843 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 846 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 849 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 849 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 853 MB/2.0 GB   13 MB/s   1m26spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 855 MB/2.0 GB   13 MB/s   1m25spulling manifest
# pulling dde5aa3fc5ff...  42% ▕██████          ▏ 857 MB/2.0 GB   13 MB/s   1m25spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 860 MB/2.0 GB   13 MB/s   1m25spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 863 MB/2.0 GB   13 MB/s   1m25spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 864 MB/2.0 GB   13 MB/s   1m25spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 865 MB/2.0 GB   15 MB/s   1m14spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 867 MB/2.0 GB   15 MB/s   1m14spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 869 MB/2.0 GB   15 MB/s   1m14spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 872 MB/2.0 GB   15 MB/s   1m14spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 875 MB/2.0 GB   15 MB/s   1m14spulling manifest
# pulling dde5aa3fc5ff...  43% ▕██████          ▏ 876 MB/2.0 GB   15 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  44% ▕██████          ▏ 880 MB/2.0 GB   15 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  44% ▕██████          ▏ 883 MB/2.0 GB   15 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  44% ▕███████         ▏ 884 MB/2.0 GB   15 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  44% ▕███████         ▏ 888 MB/2.0 GB   15 MB/s   1m13spulling manifest
# pulling dde5aa3fc5ff...  44% ▕███████         ▏ 891 MB/2.0 GB   17 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  44% ▕███████         ▏ 892 MB/2.0 GB   17 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  44% ▕███████         ▏ 895 MB/2.0 GB   17 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  44% ▕███████         ▏ 897 MB/2.0 GB   17 MB/s    1m3spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 899 MB/2.0 GB   17 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 903 MB/2.0 GB   17 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 907 MB/2.0 GB   17 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 908 MB/2.0 GB   17 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 912 MB/2.0 GB   17 MB/s    1m2spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 915 MB/2.0 GB   17 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 917 MB/2.0 GB   17 MB/s    1m1spulling manifest
# pulling dde5aa3fc5ff...  45% ▕███████         ▏ 918 MB/2.0 GB   20 MB/s     55spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 921 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 921 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 924 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 927 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 929 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 932 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 936 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  46% ▕███████         ▏ 938 MB/2.0 GB   20 MB/s     54spulling manifest
# pulling dde5aa3fc5ff...  47% ▕███████         ▏ 943 MB/2.0 GB   20 MB/s     53spulling manifest
# pulling dde5aa3fc5ff...  47% ▕███████         ▏ 947 MB/2.0 GB   22 MB/s     48spulling manifest
# pulling dde5aa3fc5ff...  47% ▕███████         ▏ 949 MB/2.0 GB   22 MB/s     48spulling manifest
# pulling dde5aa3fc5ff...  47% ▕███████         ▏ 952 MB/2.0 GB   22 MB/s     48spulling manifest
# pulling dde5aa3fc5ff...  47% ▕███████         ▏ 956 MB/2.0 GB   22 MB/s     47spulling manifest
# pulling dde5aa3fc5ff...  47% ▕███████         ▏ 958 MB/2.0 GB   22 MB/s     47spulling manifest
# ...
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051...   0% ▕                ▏    0 B/ 561 B                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success
# 0

# %%
import argparse
from langchain.vectorstores.chroma import Chroma
from langchain.prompts import ChatPromptTemplate
from langchain_community.llms.ollama import Ollama

#CHROMA_PATH = "chroma"

def query_rag(query_text: str):
    """Query the LLM using RAG with a context-based search."""
    
    print("🚀 Starting the query process...")
    
    try:
        # Prepare the embedding function and Chroma DB.
        print("📂 Loading the Chroma database...")
        embedding_function = get_embedding_function()  # Ensure this is defined elsewhere.
        db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

        # Search for relevant documents in the DB.
        print(f"🔍 Searching the database for relevant context to the query: '{query_text}'")
        results = db.similarity_search_with_score(query_text, k=5)
        if not results:
            print("⚠️ No relevant documents found in the database.")
            return "No relevant documents found to answer the query."

        # Extract the context from the search results.
        print(f"📄 Found {len(results)} relevant documents.")
        context_text = "\n\n---\n\n".join([doc.page_content for doc, _score in results])
        
        # Prepare the prompt for the LLM using the context.
        print("✍️ Preparing the prompt for the LLM...")
        prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
        prompt = prompt_template.format(context=context_text, question=query_text)

        # Query the LLM (using the Ollama model).
        print("🤖 Querying the LLM model...")
        model = Ollama(model="llama3.2")
        response_text = model.invoke(prompt)

        # Extract the source IDs from the documents.
        print("📑 Formatting the response...")
        sources = [doc.metadata.get("id", None) for doc, _score in results]
        formatted_response = f"Response: {response_text}\nSources: {sources}"
        
        print(f"✅ Query successful! Here's the response:\n{formatted_response}")
        return response_text
    
    except Exception as e:
        print(f"❌ Error occurred during the query process: {str(e)}")
        return "An error occurred during the query."

PROMPT_TEMPLATE = """
Answer the question based only on the following context:

{context}

---

Answer the question based on the above context: {question}
"""

query_text = "How did harry parents died?"
query_rag(query_text)
# Out:
# 🚀 Starting the query process...
# 📂 Loading the Chroma database...
# 🔍 Searching the database for relevant context to the query: 'How did harry parents died?'
# 📄 Found 5 relevant documents.
# ✍️ Preparing the prompt for the LLM...
# 🤖 Querying the LLM model...
# 📑 Formatting the response...
# ✅ Query successful! Here's the response:
# Response: Harry's parents, James and Lily Potter, were murdered by Voldemort. According to Harry, his father was killed first, while Voldemort tried to kill him but ended up killing his mother instead, instructing her to move aside so that he could kill the baby Harry, who miraculously survived a curse from Voldemort at the age of one year old.
# Sources: ['data/harrypotter.pdf:1126:1', 'data/harrypotter.pdf:1603:2', 'data/harrypotter.pdf:283:3', 'data/harrypotter.pdf:2825:0', 'data/harrypotter.pdf:573:1']
# "Harry's parents, James and Lily Potter, were murdered by Voldemort. According to Harry, his father was killed first, while Voldemort tried to kill him but ended up killing his mother instead, instructing her to move aside so that he could kill the baby Harry, who miraculously survived a curse from Voldemort at the age of one year old."
